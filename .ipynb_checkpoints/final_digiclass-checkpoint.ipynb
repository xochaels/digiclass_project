# %%
import pandas as pd
import os

# %%
pd.options.plotting.backend = 'plotly'
pd.set_option('display.max_columns', 500)

# %%
os.getcwd()
# Out:
# 'D:\\data_science\\project\\sales_and_profit'

# %%
df = pd.read_csv(r'D:\data_science\project\sales_and_profit\dataset\Orders.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id    customer_name    segment        country             city       state  postal_code region       product_id         category sub-category                                       product_name     sales  quantity  discount    profit
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520      Claire Gute   Consumer  United States        Henderson    Kentucky        42420  South  FUR-BO-10001798        Furniture    Bookcases                  Bush Somerset Collection Bookcase  261.9600         2      0.00   41.9136
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520      Claire Gute   Consumer  United States        Henderson    Kentucky        42420  South  FUR-CH-10000454        Furniture       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3      0.00  219.5820
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9994 non-null   int64
#  1   order_id       9994 non-null   object
#  2   order_date     9994 non-null   object
#  3   ship_date      9994 non-null   object
#  4   ship_mode      9994 non-null   object
#  5   customer_id    9994 non-null   object
#  6   customer_name  9994 non-null   object
#  7   segment        9994 non-null   object
#  8   country        9994 non-null   object
#  9   city           9994 non-null   object
#  10  state          9994 non-null   object
#  11  postal_code    9994 non-null   int64
#  12  region         9994 non-null   object
#  13  product_id     9994 non-null   object
#  14  category       9994 non-null   object
#  15  sub-category   9994 non-null   object
#  16  product_name   9994 non-null   object
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['month'] = [df['order_date'][x].month for x in range(len(df['order_date']))]

# %%
df.head()
# Out:
#    row_id        order_id order_date   ship_date       ship_mode customer_id    customer_name    segment        country             city       state  postal_code region       product_id         category sub-category                                       product_name     sales  quantity  discount    profit  month
# 0       1  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520      Claire Gute   Consumer  United States        Henderson    Kentucky        42420  South  FUR-BO-10001798        Furniture    Bookcases                  Bush Somerset Collection Bookcase  261.9600         2      0.00   41.9136     11
# 1       2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520      Claire Gute   Consumer  United States        Henderson    Kentucky        42420  South  FUR-CH-10000454        Furniture       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3      0.00  219.5820     11
# ...

# %%
tahun_2017 = df[(df['order_date'] >= '1/1/2017') & (df['order_date'] <= '12/31/2017')]

# %%
tahun_2017.head()
# Out:
#     row_id        order_id order_date   ship_date       ship_mode customer_id    customer_name      segment        country          city           state  postal_code   region       product_id         category sub-category                                       product_name    sales  quantity  discount   profit  month
# 12      13  CA-2017-114412 2017-04-15   4/20/2017  Standard Class    AA-10480     Andrew Allen     Consumer  United States       Concord  North Carolina        28027    South  OFF-PA-10002365  Office Supplies        Paper                                         Xerox 1967   15.552         3       0.2   5.4432      4
# 23      24  US-2017-156909 2017-07-16   7/18/2017    Second Class    SF-20065  Sandra Flanagan     Consumer  United States  Philadelphia    Pennsylvania        19140     East  FUR-CH-10002774        Furniture       Chairs                 Global Deluxe Stacking Chair, Gray   71.372         2       0.3  -1.0196      7
# ...

# %%
tahun_2017['month'].value_counts()
# Out:
# 12    462
# 9     459
# 11    459
# 10    298
# 6     245
# 5     242
# 3     238
# 7     226
# 8     218
# 4     203
# 1     155
# 2     107
# Name: month, dtype: int64

# %%
sort_month = tahun_2017.groupby(['month'])

# %%
sort_month.get_group(1)['profit'][:5]
# Out:
# 439       2.3094
# 515    1379.9770
# 516      13.8915
# 517       5.3820
# 518      56.3010
# Name: profit, dtype: float64

# %%
sort_month.get_group(1)['profit'].sum()
# Out:
# 7140.439099999999

# %%
count=0
for x in range(12):
    count+=1
    
count
# Out:
# 12

# %%
month_profit_sales_2017 = {'date':['Januari','Februari','Maret','April', 'Mei', 'Juni', 'Juli', 
                       'Agustus', 'September', 'Oktober', 'November','Desember'],
                      'profit':[],
                      'sales':[]}

count=0
for x in range(12):
    count+=1
    profit_month = sort_month.get_group(count)['profit'].sum()
    sales_month = sort_month.get_group(count)['sales'].sum()
    
    month_profit_sales_2017['profit'].append(profit_month)
    month_profit_sales_2017['sales'].append(sales_month)
    
month_profit_sales_2017 = pd.DataFrame(month_profit_sales_2017)

# %%
month_profit_sales_2017
# Out:
#          date      profit        sales
# 0     Januari   7140.4391   43971.3740
# 1    Februari   1613.8720   20301.1334
# 2       Maret  14751.8915   58872.3528
# 3       April    933.2900   36521.5361
# 4         Mei   6342.5828   44261.1102
# 5        Juni   8223.3357   52981.7257
# 6        Juli   6952.6212   45264.4160
# 7     Agustus   9040.9557   63120.8880
# 8   September  10991.5556   87866.6520
# 9     Oktober   9275.2755   77776.9232
# 10   November   9690.1037  118447.8250
# 11   Desember   8483.3468   83829.3188

# %%
month_profit_sales_2017.describe()
# Out:
#              profit          sales
# count     12.000000      12.000000
# mean    7786.605800   61101.271267
# std     3755.538561   26919.532133
# min      933.290000   20301.133400
# 25%     6800.111600   44188.676150
# 50%     8353.341250   55927.039250
# 75%     9378.982550   79290.022100
# max    14751.891500  118447.825000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize = (10,5))

plt.title('Profit Tahun 2017')
plt.xticks(rotation=45)

ax2 = ax.twinx()

ax.plot(month_profit_sales_2017['date'],month_profit_sales_2017['profit'], color='g', marker='o')
ax2.plot(month_profit_sales_2017['date'],month_profit_sales_2017['sales'], color='b', marker='o')

ax.set_xlabel('Bulan', color = 'r')
ax.set_ylabel('Profit', color = 'g')

ax2.set_ylabel('Sales', color = 'b')

plt.tight_layout()

plt.show()

# %%
df.head(2)
# Out:
#    row_id        order_id order_date   ship_date     ship_mode customer_id customer_name   segment        country       city     state  postal_code region       product_id   category sub-category                                       product_name   sales  quantity  discount    profit  month
# 0       1  CA-2016-152156 2016-11-08  11/11/2016  Second Class    CG-12520   Claire Gute  Consumer  United States  Henderson  Kentucky        42420  South  FUR-BO-10001798  Furniture    Bookcases                  Bush Somerset Collection Bookcase  261.96         2       0.0   41.9136     11
# 1       2  CA-2016-152156 2016-11-08  11/11/2016  Second Class    CG-12520   Claire Gute  Consumer  United States  Henderson  Kentucky        42420  South  FUR-CH-10000454  Furniture       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3       0.0  219.5820     11

# %%
def get_profit_month():
    month_profit_sales = {'date' :pd.date_range('1-2014',periods=48,freq='m'),
                          'profit':[],
                          'sales':[]}
    
    for year in [14,15,16,17]:
        tahun = df[(df['order_date'] >= f'1/1/20{year}') & (df['order_date'] <= f'12/31/20{year}')]
        sort_month = tahun.groupby(['month'])
    
        count=0
        for x in range(12):
            count+=1
            profit_month = sort_month.get_group(count)['profit'].sum()
            sales_month = sort_month.get_group(count)['sales'].sum()
            
            month_profit_sales['profit'].append(profit_month)
            month_profit_sales['sales'].append(sales_month)

    return pd.DataFrame(month_profit_sales)

# %%
month_profit_sales = get_profit_month()

# %%
month_profit_sales.head()
# Out:
#         date     profit      sales
# 0 2014-01-31  2450.1907  14236.895
# 1 2014-02-28   862.3084   4519.892
# 2 2014-03-31   498.7299  55691.009
# 3 2014-04-30  3488.8352  28295.345
# 4 2014-05-31  2738.7096  23648.287

# %%
def get_profit_month():
    month_profit_sales = {'date' :pd.date_range('1-2014',periods=48,freq='m'),
                          'profit':[],
                          'sales':[]}
    
    for year in [14,15,16,17]:
        tahun = df[(df['order_date'] >= f'1/1/20{year}') & (df['order_date'] <= f'12/31/20{year}')]
        sort_month = tahun.groupby(['month'])
    
        count=0
        for x in range(12):
            count+=1
            profit_month = sort_month.get_group(count)['profit'].sum()
            sales_month = sort_month.get_group(count)['sales'].sum()
            
            month_profit_sales['profit'].append(profit_month)
            month_profit_sales['sales'].append(sales_month)

    return pd.DataFrame(month_profit_sales)

# %%
def visualization(data,judul):
    fig, ax = plt.subplots(figsize = (10,5))

    plt.title(judul)
    plt.xticks(rotation=45)

    ax2 = ax.twinx()

    ax.plot(data['date'],data['profit'], color='g', marker='o')
    ax2.plot(data['date'],data['sales'], color='b', marker='o')

    ax.set_xlabel('Bulan', color = 'r')
    ax.set_ylabel('Profit', color = 'g')

    ax2.set_ylabel('Sales', color = 'b')

    plt.tight_layout()

    plt.show()
